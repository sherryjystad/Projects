# %%
import pandas as pd
import datetime
import numpy as np

# %%
import os
import csv

# %%
# File to Load (Remember to Change These)
data_201801_path = "Resources/201801-citibike-tripdata.csv"

nycbike_201801 = pd.read_csv(data_201801_path)

# %%
nycbike_201801.count()
# Out:
# tripduration               718994
# starttime                  718994
# stoptime                   718994
# start station id           718994
# start station name         718994
# start station latitude     718994
# start station longitude    718994
# end station id             718994
# end station name           718994
# end station latitude       718994
# end station longitude      718994
# bikeid                     718994
# usertype                   718994
# birth year                 718994
# gender                     718994
# dtype: int64

# %%
# File to Load (Remember to Change These)
data_201802_path = "Resources/201802-citibike-tripdata.csv"
nycbike_201802 = pd.read_csv(data_201802_path)

# %%
nycbike_201802.count()
# Out:
# tripduration               843114
# starttime                  843114
# stoptime                   843114
# start station id           843114
# start station name         843114
# start station latitude     843114
# start station longitude    843114
# end station id             843114
# end station name           843114
# end station latitude       843114
# end station longitude      843114
# bikeid                     843114
# usertype                   843114
# birth year                 843114
# gender                     843114
# dtype: int64

# %%
# File to Load (Remember to Change These)
data_201803_path = "Resources/201803-citibike-tripdata.csv"
nycbike_201803 = pd.read_csv(data_201803_path)

# %%
nycbike_201803.count()
# Out:
# tripduration               976672
# starttime                  976672
# stoptime                   976672
# start station id           976672
# start station name         976672
# start station latitude     976672
# start station longitude    976672
# end station id             976672
# end station name           976672
# end station latitude       976672
# end station longitude      976672
# bikeid                     976672
# usertype                   976672
# birth year                 976672
# gender                     976672
# dtype: int64

# %%
# Combine the data into a single dataset
bike_trips_df = pd.concat([nycbike_201801,nycbike_201802, nycbike_201803])

# %%
# Display the data table for preview
bike_trips_df= pd.read_csv(trips)
bike_trips_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           970  2018-01-01 13:50:57.4340  2018-01-01 14:07:08.1860
# 1           723  2018-01-01 15:33:30.1820  2018-01-01 15:45:33.3410
# 2           496  2018-01-01 15:39:18.3370  2018-01-01 15:47:35.1720
# 3           306  2018-01-01 15:40:13.3720  2018-01-01 15:45:20.1910
# 4           306  2018-01-01 18:14:51.5680  2018-01-01 18:19:57.6420
#
#    start station id start station name  start station latitude  \
# 0                72   W 52 St & 11 Ave               40.767272
# 1                72   W 52 St & 11 Ave               40.767272
# 2                72   W 52 St & 11 Ave               40.767272
# 3                72   W 52 St & 11 Ave               40.767272
# 4                72   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id         end station name  \
# 0               -73.993929             505          6 Ave & W 33 St
# ...

# %%
bike_trips_df.count()
# Out:
# tripduration               2538780
# starttime                  2538780
# stoptime                   2538780
# start station id           2538780
# start station name         2538780
# start station latitude     2538780
# start station longitude    2538780
# end station id             2538780
# end station name           2538780
# end station latitude       2538780
# end station longitude      2538780
# bikeid                     2538780
# usertype                   2538780
# birth year                 2538780
# gender                     2538780
# dtype: int64

# %%
# replace Gender (Zero=unknown; 1=male; 2=female)
bike_trips_df= bike_trips_df.replace({0: "unknown", 1: "male", 2: "female"})
bike_trips_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           970  2018-01-01 13:50:57.4340  2018-01-01 14:07:08.1860
# 1           723  2018-01-01 15:33:30.1820  2018-01-01 15:45:33.3410
# 2           496  2018-01-01 15:39:18.3370  2018-01-01 15:47:35.1720
# 3           306  2018-01-01 15:40:13.3720  2018-01-01 15:45:20.1910
# 4           306  2018-01-01 18:14:51.5680  2018-01-01 18:19:57.6420
#
#    start station id start station name  start station latitude  \
# 0                72   W 52 St & 11 Ave               40.767272
# 1                72   W 52 St & 11 Ave               40.767272
# 2                72   W 52 St & 11 Ave               40.767272
# 3                72   W 52 St & 11 Ave               40.767272
# 4                72   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id         end station name  \
# 0               -73.993929             505          6 Ave & W 33 St
# ...

# %%
bike_trips_df.to_csv("Resources/Qtr_2018_Data.csv",index=False)
