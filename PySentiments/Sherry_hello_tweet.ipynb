# %%
# Dependencies
import tweepy

# Twitter API Keys
from config import (consumer_key, 
                    consumer_secret, 
                    access_token, 
                    access_token_secret)

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Note: Twitter prevents from tweeting the same status or message multiple
# times. Be sure to change the text when testing.

# Create two status updates
api.update_with_media("Output/sentiment_friend_scatter.png")
# Out:
# {'created_at': 'Tue Oct 02 20:28:03 +0000 2018',
#  'id': 1047221695965097984,
#  'id_str': '1047221695965097984',
#  'text': 'https://t.co/dyjySSDWJx',
#  'truncated': False,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'urls': [],
#   'media': [{'id': 1047221694857789440,
#     'id_str': '1047221694857789440',
#     'indices': [0, 23],
#     'media_url': 'http://pbs.twimg.com/media/Doh6lUMUwAAyJU7.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/Doh6lUMUwAAyJU7.jpg',
#     'url': 'https://t.co/dyjySSDWJx',
#     'display_url': 'pic.twitter.com/dyjySSDWJx',
#     'expanded_url': 'https://twitter.com/sherryjystad5/status/1047221695965097984/photo/1',
#     'type': 'photo',
#     'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'large': {'w': 432, 'h': 288, 'resize': 'fit'},
#      'small': {'w': 432, 'h': 288, 'resize': 'fit'},
#      'medium': {'w': 432, 'h': 288, 'resize': 'fit'}}}]},
#  'extended_entities': {'media': [{'id': 1047221694857789440,
#     'id_str': '1047221694857789440',
#     'indices': [0, 23],
#     'media_url': 'http://pbs.twimg.com/media/Doh6lUMUwAAyJU7.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/Doh6lUMUwAAyJU7.jpg',
#     'url': 'https://t.co/dyjySSDWJx',
#     'display_url': 'pic.twitter.com/dyjySSDWJx',
#     'expanded_url': 'https://twitter.com/sherryjystad5/status/1047221695965097984/photo/1',
#     'type': 'photo',
#     'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'large': {'w': 432, 'h': 288, 'resize': 'fit'},
#      'small': {'w': 432, 'h': 288, 'resize': 'fit'},
#      'medium': {'w': 432, 'h': 288, 'resize': 'fit'}}}]},
#  'source': '<a href="https://www.google.com" rel="nofollow">KnittyWitty</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 1032694285798277122,
#   'id_str': '1032694285798277122',
#   'name': 'sherryjystad5',
#   'screen_name': 'sherryjystad5',
#   'location': '',
#   'description': '',
#   'url': 'https://t.co/yafO81z1Bz',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/yafO81z1Bz',
#       'expanded_url': 'https://www.facebook.com/sherry.jystad',
#       'display_url': 'facebook.com/sherry.jystad',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 5,
#   'friends_count': 6,
#   'listed_count': 0,
#   'created_at': 'Thu Aug 23 18:21:19 +0000 2018',
#   'favourites_count': 0,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 13,
#   'lang': 'en',
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1043172774313742337/dVHXPJyY_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1043172774313742337/dVHXPJyY_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'lang': 'und'}

# %%
# Create a friendship with another user
api.create_friendship(screen_name="@PlotBot5", follow=True)
# Out:
# {'contributors_enabled': False,
#  'created_at': 'Sat Dec 31 01:00:04 +0000 2016',
#  'default_profile': True,
#  'default_profile_image': False,
#  'description': 'Making Sense of the Twitter-Sphere. Tweet "@PlotBot5 Analyze: ______" to request. (+) = Happy. (-) = Sad/Angry. 1 Run Per Target. Created by @afhaque',
#  'entities': {'description': {'urls': []}},
#  'favourites_count': 0,
#  'follow_request_sent': False,
#  'followers_count': 47,
#  'following': True,
#  'friends_count': 22,
#  'geo_enabled': False,
#  'has_extended_profile': False,
#  'id': 814999527451148288,
#  'id_str': '814999527451148288',
#  'is_translation_enabled': False,
#  'is_translator': False,
#  'lang': 'en',
#  'listed_count': 0,
#  'location': 'New York, NY',
#  'muting': False,
#  'name': 'PlotBot5',
#  'notifications': True,
#  'profile_background_color': 'F5F8FA',
#  'profile_background_image_url': None,
#  'profile_background_image_url_https': None,
#  'profile_background_tile': False,
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/814999527451148288/1483415472',
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/815395926508470273/RdaiJEGV_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/815395926508470273/RdaiJEGV_normal.jpg',
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'protected': False,
#  'screen_name': 'PlotBot5',
#  'status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Mar 27 06:19:55 +0000 2018',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/gC3A2Yzb5b',
#      'expanded_url': 'https://twitter.com/PlotBot5/status/978516949683658752/photo/1',
#      'id': 978516947431231488,
#      'id_str': '978516947431231488',
#      'indices': [50, 73],
#      'media_url': 'http://pbs.twimg.com/media/DZRj-rJWkAAsexr.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DZRj-rJWkAAsexr.jpg',
#      'sizes': {'large': {'h': 526, 'resize': 'fit', 'w': 822},
#       'medium': {'h': 526, 'resize': 'fit', 'w': 822},
#       'small': {'h': 435, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/gC3A2Yzb5b'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 30018058,
#      'id_str': '30018058',
#      'indices': [20, 27],
#      'name': 'PayPal',
#      'screen_name': 'PayPal'},
#     {'id': 442247562,
#      'id_str': '442247562',
#      'indices': [33, 46],
#      'name': 'Girija',
#      'screen_name': 'JahnaviParab'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/gC3A2Yzb5b',
#      'expanded_url': 'https://twitter.com/PlotBot5/status/978516949683658752/photo/1',
#      'id': 978516947431231488,
#      'id_str': '978516947431231488',
#      'indices': [50, 73],
#      'media_url': 'http://pbs.twimg.com/media/DZRj-rJWkAAsexr.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DZRj-rJWkAAsexr.jpg',
#      'sizes': {'large': {'h': 526, 'resize': 'fit', 'w': 822},
#       'medium': {'h': 526, 'resize': 'fit', 'w': 822},
#       'small': {'h': 435, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/gC3A2Yzb5b'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 978516949683658752,
#   'id_str': '978516949683658752',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="https://plotbot5.herokuapp.com/" rel="nofollow">PlotBot5</a>',
#   'text': 'New Tweet Analysis: @PayPal (Thx @JahnaviParab!!) https://t.co/gC3A2Yzb5b',
#   'truncated': False},
#  'statuses_count': 51,
#  'time_zone': None,
#  'translator_type': 'none',
#  'url': None,
#  'utc_offset': None,
#  'verified': False}

# %%
# Send a direct message to another user (Hint: You will need them to
# follow your account)
api.send_direct_message(user="plotbot5", text="hiiiiiii!!!!!!")
# Out:
# {'created_at': 'Tue Mar 27 22:01:34 +0000 2018',
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'id': 978753925053497348,
#  'id_str': '978753925053497348',
#  'recipient': {'contributors_enabled': False,
#   'created_at': 'Fri Aug 24 03:01:06 +0000 2012',
#   'default_profile': True,
#   'default_profile_image': True,
#   'description': '',
#   'entities': {'description': {'urls': []}},
#   'favourites_count': 0,
#   'follow_request_sent': False,
#   'followers_count': 3,
#   'following': True,
#   'friends_count': 8,
#   'geo_enabled': False,
#   'has_extended_profile': False,
#   'id': 777278389,
#   'id_str': '777278389',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': 'en',
#   'listed_count': 0,
#   'location': '',
#   'name': 'data student',
#   'notifications': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#   'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'data_stew',
#   'statuses_count': 268,
#   'time_zone': 'Pacific Time (US & Canada)',
#   'translator_type': 'none',
#   'url': None,
#   'utc_offset': -25200,
#   'verified': False},
#  'recipient_id': 777278389,
#  'recipient_id_str': '777278389',
#  'recipient_screen_name': 'data_stew',
#  'sender': {'contributors_enabled': False,
#   'created_at': 'Fri Jul 05 14:53:38 +0000 2013',
#   'default_profile': True,
#   'default_profile_image': False,
#   'description': 'Mother, wife, lifelong learner.  Passionate educator.  Opinions and tweets are my own.',
#   'entities': {'description': {'urls': []}},
#   'favourites_count': 1163,
#   'follow_request_sent': False,
#   'followers_count': 239,
#   'following': False,
#   'friends_count': 288,
#   'geo_enabled': True,
#   'has_extended_profile': False,
#   'id': 1570660926,
#   'id_str': '1570660926',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': 'en',
#   'listed_count': 20,
#   'location': '',
#   'name': 'Ronessa Acquesta',
#   'notifications': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1570660926/1465063454',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/739155175479357440/Jq5NwBQg_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/739155175479357440/Jq5NwBQg_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'ronessaacquesta',
#   'statuses_count': 823,
#   'time_zone': 'Eastern Time (US & Canada)',
#   'translator_type': 'none',
#   'url': None,
#   'utc_offset': -14400,
#   'verified': False},
#  'sender_id': 1570660926,
#  'sender_id_str': '1570660926',
#  'sender_screen_name': 'ronessaacquesta',
#  'text': 'hiiiiiii!!!!!!'}

# %%
# Bonus: Retweet any tweet from someone else's account (Hint: You will
# need to locate a tweet's id)
target_user = "@ddjournalism"
public_tweets = api.user_timeline(target_user)
tweet_id = public_tweets[0]["id"]
api.retweet(tweet_id)
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Mar 27 22:01:35 +0000 2018',
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'urls': [],
#   'user_mentions': [{'id': 303687748,
#     'id_str': '303687748',
#     'indices': [3, 16],
#     'name': 'DataDrivenJournalism',
#     'screen_name': 'ddjournalism'},
#    {'id': 129922502,
#     'id_str': '129922502',
#     'indices': [64, 73],
#     'name': 'Nayomi Chibana',
#     'screen_name': 'nchibana'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 978753928400695296,
#  'id_str': '978753928400695296',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'retweet_count': 24,
#  'retweeted': True,
#  'retweeted_status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 25 04:27:28 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#      'expanded_url': 'https://twitter.com/i/web/status/977763875624927234',
#      'indices': [117, 140],
#      'url': 'https://t.co/WUgu5azrob'}],
#    'user_mentions': [{'id': 129922502,
#      'id_str': '129922502',
#      'indices': [46, 55],
#      'name': 'Nayomi Chibana',
#      'screen_name': 'nchibana'}]},
#   'favorite_count': 42,
#   'favorited': False,
#   'geo': None,
#   'id': 977763875624927234,
#   'id_str': '977763875624927234',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 24,
#   'retweeted': True,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'Using the most recent UN data on live births, @nchibana explored whether humans—like animals—also have mating seaso… https://t.co/WUgu5azrob',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon May 23 08:45:01 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'We are @ejcnet and we run http://t.co/1gjMNuhT, http://t.co/3sgDSxqA, data journalism mailing list (http://t.co/BsfYqRvV). Data journalism hashtag #ddj',
#    'entities': {'description': {'urls': [{'display_url': 'DataDrivenJournalism.net',
#        'expanded_url': 'http://DataDrivenJournalism.net',
#        'indices': [26, 46],
#        'url': 'http://t.co/1gjMNuhT'},
#       {'display_url': 'DataJournalismHandbook.org',
#        'expanded_url': 'http://DataJournalismHandbook.org',
#        'indices': [48, 68],
#        'url': 'http://t.co/3sgDSxqA'},
#       {'display_url': 'ejc.net/ddj-list',
#        'expanded_url': 'http://ejc.net/ddj-list',
#        'indices': [100, 120],
#        'url': 'http://t.co/BsfYqRvV'}]},
#     'url': {'urls': [{'display_url': 'datadrivenjournalism.net',
#        'expanded_url': 'http://datadrivenjournalism.net',
#        'indices': [0, 22],
#        'url': 'http://t.co/ebKj16B6AB'}]}},
#    'favourites_count': 92,
#    'follow_request_sent': False,
#    'followers_count': 26867,
#    'following': False,
#    'friends_count': 1052,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 303687748,
#    'id_str': '303687748',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 2087,
#    'location': '',
#    'name': 'DataDrivenJournalism',
#    'notifications': False,
#    'profile_background_color': 'FAFAFA',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000061362869/0a233de84ca5c53d985639c3ad940580.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000061362869/0a233de84ca5c53d985639c3ad940580.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1556110992/twitter_profilepicture_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1556110992/twitter_profilepicture_normal.png',
#    'profile_link_color': 'F5410A',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'F7F1C9',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'ddjournalism',
#    'statuses_count': 3768,
#    'time_zone': 'Brussels',
#    'translator_type': 'none',
#    'url': 'http://t.co/ebKj16B6AB',
#    'utc_offset': 7200,
#    'verified': False}},
#  'source': '<a href="https://www.google.com" rel="nofollow">sample tweet app 50000</a>',
#  'text': 'RT @ddjournalism: Using the most recent UN data on live births, @nchibana explored whether humans—like animals—also have mating seasons: ht…',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Fri Jul 05 14:53:38 +0000 2013',
#   'default_profile': True,
#   'default_profile_image': False,
#   'description': 'Mother, wife, lifelong learner.  Passionate educator.  Opinions and tweets are my own.',
#   'entities': {'description': {'urls': []}},
#   'favourites_count': 1163,
#   'follow_request_sent': False,
#   'followers_count': 239,
#   'following': False,
#   'friends_count': 288,
#   'geo_enabled': True,
#   'has_extended_profile': False,
#   'id': 1570660926,
#   'id_str': '1570660926',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': 'en',
#   'listed_count': 20,
#   'location': '',
#   'name': 'Ronessa Acquesta',
#   'notifications': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1570660926/1465063454',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/739155175479357440/Jq5NwBQg_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/739155175479357440/Jq5NwBQg_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'ronessaacquesta',
#   'statuses_count': 824,
#   'time_zone': 'Eastern Time (US & Canada)',
#   'translator_type': 'none',
#   'url': None,
#   'utc_offset': -14400,
#   'verified': False}}

# %%
# Bonus: Delete your most recent tweet (Hint: "Destroy")
my_tweets = api.user_timeline()
tweet_id = my_tweets[0]["id"]
api.destroy_status(tweet_id)
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Mar 27 22:01:35 +0000 2018',
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'urls': [],
#   'user_mentions': [{'id': 303687748,
#     'id_str': '303687748',
#     'indices': [3, 16],
#     'name': 'DataDrivenJournalism',
#     'screen_name': 'ddjournalism'},
#    {'id': 129922502,
#     'id_str': '129922502',
#     'indices': [64, 73],
#     'name': 'Nayomi Chibana',
#     'screen_name': 'nchibana'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 978753928400695296,
#  'id_str': '978753928400695296',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'retweet_count': 24,
#  'retweeted': True,
#  'retweeted_status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 25 04:27:28 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#      'expanded_url': 'https://twitter.com/i/web/status/977763875624927234',
#      'indices': [117, 140],
#      'url': 'https://t.co/WUgu5azrob'}],
#    'user_mentions': [{'id': 129922502,
#      'id_str': '129922502',
#      'indices': [46, 55],
#      'name': 'Nayomi Chibana',
#      'screen_name': 'nchibana'}]},
#   'favorite_count': 42,
#   'favorited': False,
#   'geo': None,
#   'id': 977763875624927234,
#   'id_str': '977763875624927234',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 24,
#   'retweeted': True,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'Using the most recent UN data on live births, @nchibana explored whether humans—like animals—also have mating seaso… https://t.co/WUgu5azrob',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon May 23 08:45:01 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'We are @ejcnet and we run http://t.co/1gjMNuhT, http://t.co/3sgDSxqA, data journalism mailing list (http://t.co/BsfYqRvV). Data journalism hashtag #ddj',
#    'entities': {'description': {'urls': [{'display_url': 'DataDrivenJournalism.net',
#        'expanded_url': 'http://DataDrivenJournalism.net',
#        'indices': [26, 46],
#        'url': 'http://t.co/1gjMNuhT'},
#       {'display_url': 'DataJournalismHandbook.org',
#        'expanded_url': 'http://DataJournalismHandbook.org',
#        'indices': [48, 68],
#        'url': 'http://t.co/3sgDSxqA'},
#       {'display_url': 'ejc.net/ddj-list',
#        'expanded_url': 'http://ejc.net/ddj-list',
#        'indices': [100, 120],
#        'url': 'http://t.co/BsfYqRvV'}]},
#     'url': {'urls': [{'display_url': 'datadrivenjournalism.net',
#        'expanded_url': 'http://datadrivenjournalism.net',
#        'indices': [0, 22],
#        'url': 'http://t.co/ebKj16B6AB'}]}},
#    'favourites_count': 92,
#    'follow_request_sent': False,
#    'followers_count': 26867,
#    'following': False,
#    'friends_count': 1052,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 303687748,
#    'id_str': '303687748',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 2087,
#    'location': '',
#    'name': 'DataDrivenJournalism',
#    'notifications': False,
#    'profile_background_color': 'FAFAFA',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000061362869/0a233de84ca5c53d985639c3ad940580.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000061362869/0a233de84ca5c53d985639c3ad940580.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1556110992/twitter_profilepicture_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1556110992/twitter_profilepicture_normal.png',
#    'profile_link_color': 'F5410A',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'F7F1C9',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'ddjournalism',
#    'statuses_count': 3768,
#    'time_zone': 'Brussels',
#    'translator_type': 'none',
#    'url': 'http://t.co/ebKj16B6AB',
#    'utc_offset': 7200,
#    'verified': False}},
#  'source': '<a href="https://www.google.com" rel="nofollow">sample tweet app 50000</a>',
#  'text': 'RT @ddjournalism: Using the most recent UN data on live births, @nchibana explored whether humans—like animals—also have mating seasons: ht…',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Fri Jul 05 14:53:38 +0000 2013',
#   'default_profile': True,
#   'default_profile_image': False,
#   'description': 'Mother, wife, lifelong learner.  Passionate educator.  Opinions and tweets are my own.',
#   'entities': {'description': {'urls': []}},
#   'favourites_count': 1163,
#   'follow_request_sent': False,
#   'followers_count': 239,
#   'following': False,
#   'friends_count': 288,
#   'geo_enabled': True,
#   'has_extended_profile': False,
#   'id': 1570660926,
#   'id_str': '1570660926',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': 'en',
#   'listed_count': 20,
#   'location': '',
#   'name': 'Ronessa Acquesta',
#   'notifications': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1570660926/1465063454',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/739155175479357440/Jq5NwBQg_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/739155175479357440/Jq5NwBQg_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'ronessaacquesta',
#   'statuses_count': 824,
#   'time_zone': 'Eastern Time (US & Canada)',
#   'translator_type': 'none',
#   'url': None,
#   'utc_offset': -14400,
#   'verified': False}}
